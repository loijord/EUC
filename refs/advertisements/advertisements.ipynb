# %% [markdown]
# Pasirašom duomenis iš ankstesnių nuorodų

# %%
from io import StringIO
import pandas as pd
import plotly.graph_objects as go
from IPython.display import display, Markdown

def plot_comparison(df):
    brand_coloring = {'Kingsong':'red', 'Inmotion':'green', 'Gotway':'purple', 'Leaperkim':'orange', 'Ninebot':'yellow'}
    brands = df['model'].map(lambda x: x.split(' ')[1])
    fig1 = go.Scatter(x=df['range'], y=df['price']/df['range'], mode='markers', 
                      text=[f'model: {model} <br>price: {price} <br>speed: {speed} <br>range: {range}' 
                            for model, price, speed, range in df[['model', 'price', 'speed', 'range']].values],
                      marker_color=[brand_coloring[n] for n in brands],
                      marker_size=(df['price']/5)**0.5)

    fig = go.Figure(data=[fig1])
    fig.update_layout(xaxis_title="Range", 
                      yaxis_title='Price', 
                      width=1000)
    return fig


df = pd.read_csv('../euc_data_viensrats.txt')
df2 = pd.read_csv('../EUC_ranges.txt')
df3 = pd.read_csv('../EUC_prices.txt')
df['range']=df2['expected range, overall']
df['price']=df3['price']
df
# Out:
#         brand                                              model  speed  \
# 0      Gotway                           Gotway MCM5 V2 460wh 84V   34.0
# 1      Gotway                       Begode/Gotway RS 1800Wh 100v   70.0
# 2      Gotway                 Begode/Gotway EX.N 19″ 2700Wh 100v   70.0
# 3      Gotway   Begode (Extreme Bull) Commander 20” 3600 Wh 100v   80.0
# 4      Gotway                                 Begode Mten4 750Wh   57.0
# 5      Gotway                          Gotway Nikola Plus 1800Wh   60.0
# 6      Gotway                               Gotway MCM5 800Wh V2   40.0
# 7      Gotway                 Begode(Gotway) Tesla V3 1500Wh 84V   50.0
# 8      Gotway                     Begode Master 2400Wh 134.4V V2   80.0
# 9      Gotway  Extreme Bull (Begode) X-men Yellow HT 1800 Wh ...   75.0
# 10     Gotway           Begode Master Molicel P42a 2000Wh 134.4V   80.0
# 11     Gotway                      Begode Master PRO 4800wh 134V  122.0
# ...

# %% [markdown]
# ## Skelbimų skenavimas
# Susirašom visų puslapių duomenis ranka. Įterpiam papildomus duomenis: `speed` ir `range` iš pateiktos lentelės. Jei lentelėje nėra, skaičiuojam pagal atskirą formulę arba neįtraukiam.

# %% [markdown]
# ### Skelbiu.lt
# * [Paieška: vienaratis](https://www.skelbiu.lt/skelbimai/?autocompleted=1&keywords=vienaratis&cost_min=&cost_max=&type=0&cities=0&distance=0&mainCity=0&search=1&category_id=33&user_type=0&ad_since_min=0&ad_since_max=0&visited_page=1&orderBy=1&detailsSearch=0)
# * Tikrinta: 2024 06 27
# * naujausi viršuje tik 2024m., kažkiek pridėta "atnaujinti viršuje" (vėliau daugiau pridėsiu)

# %%
txt = """link,model,price,new,speed,range
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11y-74950694.html, Inmotion V11, 1700, False, 55, 128
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v5f-74943234.html, Inmotion V5f, 450, False, 25, 31
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11-74880000.html, Inmotion V11, 949, False, 55, 128
https://www.skelbiu.lt/skelbimai/inmotion-v10f-960wh-74804856.html, Inmotion V10f 960wh, 670, False, 40, 89
https://www.skelbiu.lt/skelbimai/inmotion-v5f-74707120.html, Inmotion V5f, 380, False, 25, 31
https://www.skelbiu.lt/skelbimai/leaperkim-patton-66lbs-elektrinis-vienaratis-74680352.html, Leaperkim Patton 66lbs, 2100, True,,
https://www.skelbiu.lt/skelbimai/vienaratis-kingsong-s18-74666740.html, Kingsong s18, 1350, False, 50, 102
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11-74623026.html, Inmotion v11, 900, False, 55, 128
https://www.skelbiu.lt/skelbimai/leaperkim-sherman-s-66lbs-elektrinis-vienaratis-74605922.html, Leaperkim sherman s 66lbs, 2800, True,,
https://www.skelbiu.lt/skelbimai/vienaratis-riedis-ninebot-tobulas-74583108.html, Ninebot Z10, 790, False, 45, 88
https://www.skelbiu.lt/skelbimai/vienaratis-begode-nikola-plus-100v-1800wh-74547764.html, Gotway nikola plus 100v 1800wh, 1150, False
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-gotway-nikola-plus-100v-74486158.html, Gotway nikola plus 100v, 900, False
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-king-song-s22-pro-74448292.html, Kingsong S22 Pro, 2000, False, 70, 180
https://www.skelbiu.lt/skelbimai/vienaraciu-karalius-gotway-nikola-100v-1800wh-74382452.html, Gotway Nikola 100v 1800wh, 1000, False, 60, 156
https://www.skelbiu.lt/skelbimai/inmotion-v11-vienaratis-74225790.html, Inmotion v11, 850, False, 55, 128
https://www.skelbiu.lt/skelbimai/vienaratis-riedis-gotway-begode-msp-100v-74106918.html, Gotway (Begode) Msp 100v, 810, False, 60, 156
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-euc-gotway-tesla-v2-73997334.html, Gotway Tesla V2, 750, False, 45, 96
https://www.skelbiu.lt/skelbimai/kingsong-s22-73934275.html, Kingsong S22, 1700, False, 70, 180
https://www.skelbiu.lt/skelbimai/vienaratis-riedis-73716927.html, Inmotion V10F, 885, False, 40, 89
https://www.skelbiu.lt/skelbimai/begode-master-v2-elektrinis-vienaratis-73384527.html, Gotway Begode Master V2, 2300, False, 80, 186
https://www.skelbiu.lt/skelbimai/vienaratis-ninebot-z10-73216269.html, Ninebot z10, 1050, False, 45, 88
https://www.skelbiu.lt/skelbimai/vienaratis-gotway-mten3-512wh-84v-72920108.html, Gotway Mten3 512wh/84v, 500, False, 35, 52.5
https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11-74623026.html, Inmotion V11, 900, False, 55, 128
https://www.skelbiu.lt/skelbimai/vienaratis-segway-ninebot-one-z10-70070261.html, Ninebot one z10, 1200, False, 45, 88
https://www.skelbiu.lt/skelbimai/inmotion-v13-v12ht-vienaratis-70775199.html, Inmotion V13, 2999, True, 90, 203
https://www.skelbiu.lt/skelbimai/inmotion-v13-v12ht-vienaratis-70775199.html, Inmotion V12, 1850, True, 70, 147"""

data_skelbiu = StringIO(txt) 
df_skelbiu = pd.read_csv(data_skelbiu, sep=",")
df_skelbiu['link'] = df_skelbiu['link'].apply(lambda x: '[Link]('+x+')')
display(Markdown(df_skelbiu.to_markdown().replace('nan', '')))
# Out:
# |    | link                                                                                                   | model                          |   price | new   |   speed |   range |
# |---:|:-------------------------------------------------------------------------------------------------------|:-------------------------------|--------:|:------|--------:|--------:|
# |  0 | [Link](https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11y-74950694.html)             | Inmotion V11                   |    1700 | False |      55 |   128   |
# |  1 | [Link](https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v5f-74943234.html)              | Inmotion V5f                   |     450 | False |      25 |    31   |
# |  2 | [Link](https://www.skelbiu.lt/skelbimai/elektrinis-vienaratis-inmotion-v11-74880000.html)              | Inmotion V11                   |     949 | False |      55 |   128   |
# ...

# %%
fig = plot_comparison(df_skelbiu)
path = f'advertisement_plots/skelbiu.html'
with open(path, "w", encoding="utf-8") as f: 
    f.write(fig.to_html())

# %%
# %%HTML
# <iframe width=1000 height=500 src="./advertisement_plots/skelbiu.html" frameborder="0"></iframe>
# Out:
# <iframe width=1000 height=500 src="./advertisement_plots/skelbiu.html" frameborder="0"></iframe>

# %%
#Leaperkim Patton 66lbs  
#leaperkim sherman s 66lbs
#Gotway nikola plus 100v 1800w
#Gotway nikola plus

# %% [markdown]
# ### ss.lv
# * Paieška: [Kingsong](https://www.ss.lv/lv/search-result/?q=kingsong). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=kingsong&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Gotway](https://www.ss.lv/lv/search-result/?q=gotway). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=gotway&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Begode](https://www.ss.lv/lv/search-result/?q=begode). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=begode&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Inmotion](https://www.ss.lv/lv/search-result/?q=inmotion). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=inmotion&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Ninebot](https://www.ss.lv/lv/search-result/?q=ninebot). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=ninebot&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Leaperkim](https://www.ss.lv/lv/search-result/?q=leaperkim). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=leaperkim&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)
# * Paieška: [Sherman](https://www.ss.lv/lv/search-result/?q=gotway). [Vertimas](https://www-ss-lv.translate.goog/lv/search-result/?q=sherman&_x_tr_sl=lv&_x_tr_tl=lt&_x_tr_hl=lt&_x_tr_pto=wapp)

# %%
txt = """link,model,price,new,speed,range
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/ccjocg.html, Kingsong 18L, 600, False, 50, 95
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cxponb.html, Kingsong S22, 1000, False, 70, 180
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdxejn.html, Gotway Master, 2200, False,,
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdxedx.html, Gotway Mten4, 699, True, 57, 76
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/ccoeec.html, Gotway Mcm4, 299, False,,
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/bgcobk.html, Gotway Mcm5 v2 800wh, 720, False, 40, 75
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cxxedi.html, Gotway Ex N 2700Wh 100v, 1950, False, 70, 213
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdcgnd.html, Inmotion v8s, 700, False, 35, 72
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdcfox.html, Inmotion v11, 1300, False, 55, 128
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cbgekh.html, Ninebot Z10, 600, False, 45, 88
https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/bmklgx.html, Ninebot Z10, 1120, True, 45, 88"""


data_lv = StringIO(txt) 
df_lv = pd.read_csv(data_lv, sep=",")
df_lv['link'] = df_lv['link'].apply(lambda x: '[Link]('+x+')')
display(Markdown(df_lv.to_markdown().replace('nan', '')))
# Out:
# |    | link                                                                              | model                   |   price | new   |   speed |   range |
# |---:|:----------------------------------------------------------------------------------|:------------------------|--------:|:------|--------:|--------:|
# |  0 | [Link](https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/ccjocg.html) | Kingsong 18L            |     600 | False |      50 |      95 |
# |  1 | [Link](https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cxponb.html) | Kingsong S22            |    1000 | False |      70 |     180 |
# |  2 | [Link](https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdxejn.html) | Gotway Master           |    2200 | False |      |      |
# |  3 | [Link](https://www.ss.lv/msg/lv/transport/bycycles/hybrid-electrical/cdxedx.html) | Gotway Mten4            |     699 | True  |      57 |      76 |
# ...

# %%
fig = plot_comparison(df_lv)
path = f'advertisement_plots/lv.html'
with open(path, "w", encoding="utf-8") as f: 
    f.write(fig.to_html())

# %%
# %%HTML
# <iframe width=1000 height=500 src="./advertisement_plots/lv.html" frameborder="0"></iframe>
# Out:
# <iframe width=1000 height=500 src="./advertisement_plots/lv.html" frameborder="0"></iframe>

# %%
#Begode Master
#Gotway Mcm4

# %%
# Skelbimų pokyčiai
Vėliau...
